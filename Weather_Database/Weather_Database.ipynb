# %% [markdown]
# # Deliverable 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 719

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=29364cbe7cc686003a1aabd7b3d8dbc4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop Through the List of Cities and Build the City URL
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          #"Date": city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | honiara
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | teloloapan
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | jinchang
# Processing Record 9 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | atasu
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | meulaboh
# Processing Record 17 of Set 1 | chapais
# Processing Record 18 of Set 1 | lasa
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | yumen
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | christiana
# Processing Record 29 of Set 1 | bacolod
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | batagay-alyta
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | khiri mat
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | abu samrah
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | karpathos
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | half moon bay
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | port macquarie
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | pisco
# Processing Record 1 of Set 2 | te anau
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | ahome
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | salinopolis
# Processing Record 12 of Set 2 | teseney
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | bolobo
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | barabinsk
# Processing Record 17 of Set 2 | cabrero
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | nishihara
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | general jose eduvigis diaz
# Processing Record 22 of Set 2 | banjar
# Processing Record 23 of Set 2 | saint-augustin
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 2 | dingle
# Processing Record 27 of Set 2 | saint anthony
# Processing Record 28 of Set 2 | cayenne
# Processing Record 29 of Set 2 | huesca
# Processing Record 30 of Set 2 | luangwa
# Processing Record 31 of Set 2 | ambilobe
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | tura
# Processing Record 35 of Set 2 | bindura
# Processing Record 36 of Set 2 | montefiascone
# Processing Record 37 of Set 2 | kuah
# Processing Record 38 of Set 2 | kamina
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | poykovskiy
# Processing Record 42 of Set 2 | talakan
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | la esperanza
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | constitucion
# Processing Record 47 of Set 2 | mount isa
# Processing Record 48 of Set 2 | amarante do maranhao
# Processing Record 49 of Set 2 | oktyabrskiy
# Processing Record 50 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 3 | zyryanka
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | izberbash
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | ratnagiri
# Processing Record 9 of Set 3 | moose factory
# Processing Record 10 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | santa fe
# Processing Record 13 of Set 3 | rimbey
# Processing Record 14 of Set 3 | barra do bugres
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | palana
# Processing Record 17 of Set 3 | auki
# Processing Record 18 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 3 | ixtapa
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | cap malheureux
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | belmonte
# Processing Record 25 of Set 3 | mahibadhoo
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | woodward
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | kozhva
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | mitu
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 3 | skjervoy
# Processing Record 41 of Set 3 | bo
# City not found. Skipping...
# Processing Record 42 of Set 3 | bac lieu
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | baiyin
# Processing Record 45 of Set 3 | sabang
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | coihaique
# Processing Record 48 of Set 3 | camacupa
# Processing Record 49 of Set 3 | west bay
# Processing Record 50 of Set 3 | novoagansk
# Processing Record 1 of Set 4 | beyneu
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | cidreira
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | lodja
# Processing Record 6 of Set 4 | chivay
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | mabaruma
# Processing Record 11 of Set 4 | kloulklubed
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | calvia
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | arman
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | subottsi
# Processing Record 18 of Set 4 | viedma
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | champerico
# Processing Record 21 of Set 4 | grande prairie
# Processing Record 22 of Set 4 | zhangjiakou
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | amapa
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | sinnamary
# Processing Record 28 of Set 4 | palmer
# Processing Record 29 of Set 4 | mazatlan
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | nanakuli
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | okhotsk
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | el zapote
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | wad rawah
# Processing Record 39 of Set 4 | wolkersdorf
# Processing Record 40 of Set 4 | kambia
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | vestmannaeyjar
# Processing Record 43 of Set 4 | yar-sale
# Processing Record 44 of Set 4 | konstantinovka
# Processing Record 45 of Set 4 | havoysund
# Processing Record 46 of Set 4 | prainha
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | zaysan
# Processing Record 49 of Set 4 | butaritari
# Processing Record 50 of Set 4 | marsh harbour
# Processing Record 1 of Set 5 | axim
# Processing Record 2 of Set 5 | camana
# Processing Record 3 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 5 | victor harbor
# Processing Record 5 of Set 5 | lakatoro
# Processing Record 6 of Set 5 | shelkovskaya
# Processing Record 7 of Set 5 | caravelas
# Processing Record 8 of Set 5 | komsomolskiy
# Processing Record 9 of Set 5 | mehamn
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 5 | namibe
# Processing Record 14 of Set 5 | aswan
# Processing Record 15 of Set 5 | umm lajj
# Processing Record 16 of Set 5 | northam
# Processing Record 17 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 5 | nagina
# Processing Record 19 of Set 5 | omboue
# Processing Record 20 of Set 5 | arrifes
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | sabha
# Processing Record 23 of Set 5 | benguela
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | palivere
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | sorong
# Processing Record 28 of Set 5 | port lincoln
# Processing Record 29 of Set 5 | acapulco
# Processing Record 30 of Set 5 | oskemen
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | hunchun
# Processing Record 33 of Set 5 | sambava
# Processing Record 34 of Set 5 | bundaberg
# Processing Record 35 of Set 5 | abu kamal
# Processing Record 36 of Set 5 | baoding
# Processing Record 37 of Set 5 | junnar
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | villazon
# Processing Record 40 of Set 5 | hambantota
# Processing Record 41 of Set 5 | sitka
# Processing Record 42 of Set 5 | plover
# Processing Record 43 of Set 5 | thompson
# Processing Record 44 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | tingi
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 5 | guaruja
# Processing Record 50 of Set 5 | bertoua
# Processing Record 1 of Set 6 | nelson bay
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | juba
# Processing Record 4 of Set 6 | srednekolymsk
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | bima
# Processing Record 7 of Set 6 | ostersund
# Processing Record 8 of Set 6 | jacareacanga
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | fairbanks
# Processing Record 11 of Set 6 | inhambane
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | yeppoon
# Processing Record 14 of Set 6 | itarema
# Processing Record 15 of Set 6 | werda
# Processing Record 16 of Set 6 | verkhnevilyuysk
# Processing Record 17 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | pa sang
# Processing Record 20 of Set 6 | letterkenny
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | sretensk
# Processing Record 23 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 24 of Set 6 | camargo
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 27 of Set 6 | copiapo
# Processing Record 28 of Set 6 | husavik
# Processing Record 29 of Set 6 | yuancheng
# Processing Record 30 of Set 6 | kilmez
# City not found. Skipping...
# Processing Record 31 of Set 6 | kasempa
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | dubrovka
# Processing Record 34 of Set 6 | christchurch
# Processing Record 35 of Set 6 | findlay
# Processing Record 36 of Set 6 | waipawa
# Processing Record 37 of Set 6 | hami
# Processing Record 38 of Set 6 | nemuro
# Processing Record 39 of Set 6 | joshimath
# Processing Record 40 of Set 6 | nefteyugansk
# Processing Record 41 of Set 6 | vega de alatorre
# Processing Record 42 of Set 6 | roswell
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | curvelo
# Processing Record 45 of Set 6 | saint-philippe
# Processing Record 46 of Set 6 | olafsvik
# Processing Record 47 of Set 6 | hasaki
# Processing Record 48 of Set 6 | athabasca
# Processing Record 49 of Set 6 | las vegas
# Processing Record 50 of Set 6 | nome
# Processing Record 1 of Set 7 | indi
# Processing Record 2 of Set 7 | kargat
# Processing Record 3 of Set 7 | medfield
# Processing Record 4 of Set 7 | razole
# Processing Record 5 of Set 7 | roma
# Processing Record 6 of Set 7 | pulivendla
# Processing Record 7 of Set 7 | san cristobal
# Processing Record 8 of Set 7 | kuching
# Processing Record 9 of Set 7 | bousso
# Processing Record 10 of Set 7 | lulea
# Processing Record 11 of Set 7 | marataizes
# Processing Record 12 of Set 7 | kushmurun
# Processing Record 13 of Set 7 | oliveira dos brejinhos
# Processing Record 14 of Set 7 | ushtobe
# Processing Record 15 of Set 7 | lufilufi
# Processing Record 16 of Set 7 | nantucket
# Processing Record 17 of Set 7 | grand gaube
# Processing Record 18 of Set 7 | ola
# Processing Record 19 of Set 7 | karasjok
# Processing Record 20 of Set 7 | yichang
# Processing Record 21 of Set 7 | ler
# Processing Record 22 of Set 7 | haines junction
# Processing Record 23 of Set 7 | warrnambool
# Processing Record 24 of Set 7 | najran
# Processing Record 25 of Set 7 | matara
# Processing Record 26 of Set 7 | rio gallegos
# Processing Record 27 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 28 of Set 7 | maldonado
# Processing Record 29 of Set 7 | sibolga
# Processing Record 30 of Set 7 | lalmohan
# Processing Record 31 of Set 7 | shahr-e babak
# Processing Record 32 of Set 7 | wagar
# Processing Record 33 of Set 7 | katobu
# Processing Record 34 of Set 7 | qaanaaq
# Processing Record 35 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 7 | glendive
# Processing Record 37 of Set 7 | camacha
# Processing Record 38 of Set 7 | kaniama
# Processing Record 39 of Set 7 | maxixe
# Processing Record 40 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 7 | japura
# Processing Record 42 of Set 7 | lensk
# Processing Record 43 of Set 7 | huarmey
# Processing Record 44 of Set 7 | nipawin
# Processing Record 45 of Set 7 | leningradskiy
# Processing Record 46 of Set 7 | storforshei
# Processing Record 47 of Set 7 | saskylakh
# Processing Record 48 of Set 7 | selfoss
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | shimoda
# Processing Record 2 of Set 8 | pacific grove
# Processing Record 3 of Set 8 | gerash
# Processing Record 4 of Set 8 | umm kaddadah
# Processing Record 5 of Set 8 | teya
# Processing Record 6 of Set 8 | eyl
# Processing Record 7 of Set 8 | algiers
# Processing Record 8 of Set 8 | mitake
# Processing Record 9 of Set 8 | alofi
# Processing Record 10 of Set 8 | daru
# Processing Record 11 of Set 8 | mamakan
# Processing Record 12 of Set 8 | finschhafen
# Processing Record 13 of Set 8 | sao filipe
# Processing Record 14 of Set 8 | bagotville
# Processing Record 15 of Set 8 | pafos
# Processing Record 16 of Set 8 | cherskiy
# Processing Record 17 of Set 8 | pangnirtung
# Processing Record 18 of Set 8 | kununurra
# Processing Record 19 of Set 8 | talnakh
# Processing Record 20 of Set 8 | ust-tsilma
# Processing Record 21 of Set 8 | college
# Processing Record 22 of Set 8 | dikson
# Processing Record 23 of Set 8 | pescara
# Processing Record 24 of Set 8 | churapcha
# Processing Record 25 of Set 8 | sobolevo
# Processing Record 26 of Set 8 | beisfjord
# Processing Record 27 of Set 8 | tabou
# Processing Record 28 of Set 8 | skibbereen
# Processing Record 29 of Set 8 | nyandoma
# Processing Record 30 of Set 8 | riyadh
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | dosso
# Processing Record 33 of Set 8 | san ramon
# Processing Record 34 of Set 8 | arroio grande
# Processing Record 35 of Set 8 | portobelo
# Processing Record 36 of Set 8 | cascais
# Processing Record 37 of Set 8 | mizdah
# Processing Record 38 of Set 8 | bapatla
# Processing Record 39 of Set 8 | whitehorse
# Processing Record 40 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 8 | souillac
# Processing Record 42 of Set 8 | barra do corda
# Processing Record 43 of Set 8 | vanimo
# Processing Record 44 of Set 8 | dharmabad
# Processing Record 45 of Set 8 | kurilsk
# Processing Record 46 of Set 8 | halifax
# Processing Record 47 of Set 8 | morondava
# Processing Record 48 of Set 8 | khatanga
# Processing Record 49 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 8 | trapani
# Processing Record 1 of Set 9 | sanandaj
# Processing Record 2 of Set 9 | machilipatnam
# Processing Record 3 of Set 9 | shenyang
# Processing Record 4 of Set 9 | nuevitas
# Processing Record 5 of Set 9 | namatanai
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | correntina
# Processing Record 8 of Set 9 | salalah
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | port-cartier
# Processing Record 11 of Set 9 | uthal
# Processing Record 12 of Set 9 | labuhan
# Processing Record 13 of Set 9 | siocon
# Processing Record 14 of Set 9 | muli
# Processing Record 15 of Set 9 | yerofey pavlovich
# Processing Record 16 of Set 9 | valdivia
# Processing Record 17 of Set 9 | kuytun
# Processing Record 18 of Set 9 | iraray
# Processing Record 19 of Set 9 | esperance
# Processing Record 20 of Set 9 | broken hill
# Processing Record 21 of Set 9 | dunedin
# Processing Record 22 of Set 9 | nakamura
# Processing Record 23 of Set 9 | curuca
# Processing Record 24 of Set 9 | finspang
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | puerto escondido
# Processing Record 27 of Set 9 | celestun
# Processing Record 28 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 9 | okha
# Processing Record 30 of Set 9 | chabahar
# Processing Record 31 of Set 9 | saurimo
# Processing Record 32 of Set 9 | kerteminde
# Processing Record 33 of Set 9 | quata
# Processing Record 34 of Set 9 | lukulu
# Processing Record 35 of Set 9 | rabo de peixe
# Processing Record 36 of Set 9 | taoudenni
# Processing Record 37 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 9 | khislavichi
# Processing Record 39 of Set 9 | bossangoa
# Processing Record 40 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | harper
# Processing Record 42 of Set 9 | iralaya
# Processing Record 43 of Set 9 | nyimba
# Processing Record 44 of Set 9 | cheremukhovo
# Processing Record 45 of Set 9 | yelnya
# Processing Record 46 of Set 9 | kupang
# Processing Record 47 of Set 9 | vuktyl
# Processing Record 48 of Set 9 | inuvik
# Processing Record 49 of Set 9 | houston
# Processing Record 50 of Set 9 | terra santa
# Processing Record 1 of Set 10 | altamont
# Processing Record 2 of Set 10 | calvinia
# Processing Record 3 of Set 10 | samarai
# Processing Record 4 of Set 10 | quesnel
# Processing Record 5 of Set 10 | alice springs
# Processing Record 6 of Set 10 | bosaso
# Processing Record 7 of Set 10 | avera
# Processing Record 8 of Set 10 | nanortalik
# Processing Record 9 of Set 10 | vila
# Processing Record 10 of Set 10 | bartica
# Processing Record 11 of Set 10 | sterling
# Processing Record 12 of Set 10 | augusta
# Processing Record 13 of Set 10 | bembereke
# Processing Record 14 of Set 10 | port-gentil
# Processing Record 15 of Set 10 | walvis bay
# Processing Record 16 of Set 10 | krasnoselkup
# Processing Record 17 of Set 10 | kozelsk
# Processing Record 18 of Set 10 | bharatpur
# Processing Record 19 of Set 10 | la ronge
# Processing Record 20 of Set 10 | trelew
# Processing Record 21 of Set 10 | truth or consequences
# Processing Record 22 of Set 10 | baghdad
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | reconquista
# Processing Record 25 of Set 10 | berlevag
# Processing Record 26 of Set 10 | bom jesus
# Processing Record 27 of Set 10 | road town
# Processing Record 28 of Set 10 | eureka
# Processing Record 29 of Set 10 | salyan
# Processing Record 30 of Set 10 | san jose
# Processing Record 31 of Set 10 | severo-kurilsk
# Processing Record 32 of Set 10 | fayaoue
# Processing Record 33 of Set 10 | la maddalena
# Processing Record 34 of Set 10 | bassano
# Processing Record 35 of Set 10 | san matias
# Processing Record 36 of Set 10 | sao felix do xingu
# Processing Record 37 of Set 10 | khromtau
# Processing Record 38 of Set 10 | luanda
# Processing Record 39 of Set 10 | kirakira
# Processing Record 40 of Set 10 | nioro
# Processing Record 41 of Set 10 | timra
# Processing Record 42 of Set 10 | mnogovershinnyy
# Processing Record 43 of Set 10 | novobirilyussy
# Processing Record 44 of Set 10 | chuy
# Processing Record 45 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 10 | kade
# Processing Record 47 of Set 10 | ilebo
# Processing Record 48 of Set 10 | lagoa
# Processing Record 49 of Set 10 | santa vitoria do palmar
# Processing Record 50 of Set 10 | selyatino
# Processing Record 1 of Set 11 | njeru
# Processing Record 2 of Set 11 | beaune
# Processing Record 3 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 11 | sasovo
# Processing Record 5 of Set 11 | wattegama
# Processing Record 6 of Set 11 | ballina
# Processing Record 7 of Set 11 | karpogory
# Processing Record 8 of Set 11 | comodoro rivadavia
# Processing Record 9 of Set 11 | sazonovo
# Processing Record 10 of Set 11 | kaitangata
# Processing Record 11 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 11 | souris
# Processing Record 13 of Set 11 | manta
# Processing Record 14 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 11 | pemba
# Processing Record 16 of Set 11 | sioux lookout
# Processing Record 17 of Set 11 | hammerfest
# Processing Record 18 of Set 11 | goure
# Processing Record 19 of Set 11 | chara
# Processing Record 20 of Set 11 | angoche
# Processing Record 21 of Set 11 | portland
# Processing Record 22 of Set 11 | pangody
# Processing Record 23 of Set 11 | aliwal north
# Processing Record 24 of Set 11 | verkhnyaya inta
# Processing Record 25 of Set 11 | dahod
# Processing Record 26 of Set 11 | tra vinh
# Processing Record 27 of Set 11 | santa rosalia
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | zapolyarnyy
# Processing Record 30 of Set 11 | nago
# Processing Record 31 of Set 11 | gat
# Processing Record 32 of Set 11 | trairi
# Processing Record 33 of Set 11 | peniche
# Processing Record 34 of Set 11 | warrington
# Processing Record 35 of Set 11 | sinazongwe
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | tornio
# Processing Record 38 of Set 11 | rey bouba
# Processing Record 39 of Set 11 | terrace
# Processing Record 40 of Set 11 | altamira
# Processing Record 41 of Set 11 | taburao
# City not found. Skipping...
# Processing Record 42 of Set 11 | plaridel
# Processing Record 43 of Set 11 | muncar
# Processing Record 44 of Set 11 | wilmington
# Processing Record 45 of Set 11 | richard toll
# City not found. Skipping...
# Processing Record 46 of Set 11 | broome
# Processing Record 47 of Set 11 | kribi
# Processing Record 48 of Set 11 | mgachi
# Processing Record 49 of Set 11 | chapleau
# Processing Record 50 of Set 11 | keroka
# Processing Record 1 of Set 12 | det udom
# Processing Record 2 of Set 12 | inzhavino
# Processing Record 3 of Set 12 | chino hills
# Processing Record 4 of Set 12 | dukat
# Processing Record 5 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 12 | san carlos de bariloche
# Processing Record 7 of Set 12 | kodinsk
# Processing Record 8 of Set 12 | staunton
# Processing Record 9 of Set 12 | ulagan
# Processing Record 10 of Set 12 | dalvik
# Processing Record 11 of Set 12 | dubbo
# Processing Record 12 of Set 12 | sao gabriel da cachoeira
# Processing Record 13 of Set 12 | bomi
# Processing Record 14 of Set 12 | karratha
# Processing Record 15 of Set 12 | bagdarin
# Processing Record 16 of Set 12 | grindavik
# Processing Record 17 of Set 12 | shuangcheng
# Processing Record 18 of Set 12 | segou
# Processing Record 19 of Set 12 | wanning
# Processing Record 20 of Set 12 | qaqortoq
# Processing Record 21 of Set 12 | kruisfontein
# Processing Record 22 of Set 12 | rzhaksa
# Processing Record 23 of Set 12 | newport
# Processing Record 24 of Set 12 | akdepe
# Processing Record 25 of Set 12 | guayaquil
# Processing Record 26 of Set 12 | luwuk
# Processing Record 27 of Set 12 | amberley
# Processing Record 28 of Set 12 | audru
# Processing Record 29 of Set 12 | porto novo
# Processing Record 30 of Set 12 | meridian
# Processing Record 31 of Set 12 | berkakit
# Processing Record 32 of Set 12 | lata
# Processing Record 33 of Set 12 | isangel
# Processing Record 34 of Set 12 | mangrol
# Processing Record 35 of Set 12 | lewiston
# Processing Record 36 of Set 12 | staryy nadym
# Processing Record 37 of Set 12 | shorkot
# Processing Record 38 of Set 12 | roebourne
# Processing Record 39 of Set 12 | utena
# Processing Record 40 of Set 12 | mandalgovi
# Processing Record 41 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 12 | ajaccio
# Processing Record 43 of Set 12 | yanam
# Processing Record 44 of Set 12 | nouna
# Processing Record 45 of Set 12 | cabedelo
# Processing Record 46 of Set 12 | tianpeng
# Processing Record 47 of Set 12 | tual
# Processing Record 48 of Set 12 | shingu
# Processing Record 49 of Set 12 | senges
# Processing Record 50 of Set 12 | livny
# Processing Record 1 of Set 13 | emba
# Processing Record 2 of Set 13 | boa vista
# Processing Record 3 of Set 13 | casma
# Processing Record 4 of Set 13 | kuandian
# Processing Record 5 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 13 | sokoto
# Processing Record 7 of Set 13 | evreux
# Processing Record 8 of Set 13 | agirish
# Processing Record 9 of Set 13 | ciechocinek
# Processing Record 10 of Set 13 | mollendo
# Processing Record 11 of Set 13 | polyarnyy
# Processing Record 12 of Set 13 | holme
# Processing Record 13 of Set 13 | marawi
# Processing Record 14 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 13 | ahipara
# Processing Record 16 of Set 13 | abbeville
# Processing Record 17 of Set 13 | coahuayana
# Processing Record 18 of Set 13 | conceicao da barra
# Processing Record 19 of Set 13 | bandarbeyla
# Processing Record 20 of Set 13 | torbat-e jam
# Processing Record 21 of Set 13 | bartow
# Processing Record 22 of Set 13 | ust-nera
# Processing Record 23 of Set 13 | qasigiannguit
# Processing Record 24 of Set 13 | akureyri
# Processing Record 25 of Set 13 | goderich
# Processing Record 26 of Set 13 | berdigestyakh
# Processing Record 27 of Set 13 | pacifica
# Processing Record 28 of Set 13 | mitsamiouli
# Processing Record 29 of Set 13 | ridgecrest
# Processing Record 30 of Set 13 | hovd
# Processing Record 31 of Set 13 | ossora
# Processing Record 32 of Set 13 | oktyabrskoye
# Processing Record 33 of Set 13 | lokot
# Processing Record 34 of Set 13 | udachnyy
# Processing Record 35 of Set 13 | colac
# Processing Record 36 of Set 13 | paris
# Processing Record 37 of Set 13 | kurumkan
# Processing Record 38 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 13 | mahenge
# Processing Record 40 of Set 13 | chany
# Processing Record 41 of Set 13 | kaura namoda
# Processing Record 42 of Set 13 | petauke
# Processing Record 43 of Set 13 | atmakur
# Processing Record 44 of Set 13 | pokhara
# Processing Record 45 of Set 13 | igrim
# Processing Record 46 of Set 13 | tooele
# Processing Record 47 of Set 13 | jiujiang
# Processing Record 48 of Set 13 | gweru
# Processing Record 49 of Set 13 | guerrero
# Processing Record 50 of Set 13 | jiuquan
# Processing Record 1 of Set 14 | ust-ishim
# Processing Record 2 of Set 14 | chihuahua
# Processing Record 3 of Set 14 | carlsbad
# Processing Record 4 of Set 14 | lazaro cardenas
# Processing Record 5 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 14 | silifke
# Processing Record 7 of Set 14 | seoul
# Processing Record 8 of Set 14 | flinders
# Processing Record 9 of Set 14 | adrar
# Processing Record 10 of Set 14 | noshiro
# Processing Record 11 of Set 14 | santiago del estero
# Processing Record 12 of Set 14 | baykit
# Processing Record 13 of Set 14 | careiro da varzea
# Processing Record 14 of Set 14 | rab
# City not found. Skipping...
# Processing Record 15 of Set 14 | sisimiut
# Processing Record 16 of Set 14 | ketchikan
# Processing Record 17 of Set 14 | redlands
# Processing Record 18 of Set 14 | thunder bay
# Processing Record 19 of Set 14 | huancavelica
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | san-pedro
# Processing Record 22 of Set 14 | dzhebariki-khaya
# Processing Record 23 of Set 14 | saryg-sep
# Processing Record 24 of Set 14 | empangeni
# Processing Record 25 of Set 14 | puli
# Processing Record 26 of Set 14 | winneba
# Processing Record 27 of Set 14 | sulangan
# Processing Record 28 of Set 14 | aki
# Processing Record 29 of Set 14 | barra
# Processing Record 30 of Set 14 | tingo maria
# Processing Record 31 of Set 14 | vitorino freire
# Processing Record 32 of Set 14 | machali
# Processing Record 33 of Set 14 | virginia beach
# Processing Record 34 of Set 14 | terney
# Processing Record 35 of Set 14 | kati
# Processing Record 36 of Set 14 | rome
# Processing Record 37 of Set 14 | pochutla
# Processing Record 38 of Set 14 | hanzhong
# Processing Record 39 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 14 | ahuimanu
# Processing Record 41 of Set 14 | mount gambier
# Processing Record 42 of Set 14 | kabare
# Processing Record 43 of Set 14 | sosnovo-ozerskoye
# Processing Record 44 of Set 14 | kargasok
# Processing Record 45 of Set 14 | acarau
# Processing Record 46 of Set 14 | tukrah
# Processing Record 47 of Set 14 | makaryev
# Processing Record 48 of Set 14 | cabra
# Processing Record 49 of Set 14 | springdale
# Processing Record 50 of Set 14 | rebrikha
# Processing Record 1 of Set 15 | sao joao do paraiso
# Processing Record 2 of Set 15 | cookeville
# Processing Record 3 of Set 15 | kodino
# Processing Record 4 of Set 15 | sainte-marie
# Processing Record 5 of Set 15 | west wendover
# Processing Record 6 of Set 15 | kawai
# Processing Record 7 of Set 15 | saint albans
# Processing Record 8 of Set 15 | matamoros
# Processing Record 9 of Set 15 | catamarca
# Processing Record 10 of Set 15 | vryburg
# Processing Record 11 of Set 15 | russell
# Processing Record 12 of Set 15 | cap-aux-meules
# Processing Record 13 of Set 15 | ca mau
# Processing Record 14 of Set 15 | ikom
# Processing Record 15 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 15 | praia da vitoria
# Processing Record 17 of Set 15 | rorvik
# Processing Record 18 of Set 15 | bintulu
# Processing Record 19 of Set 15 | zhangye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 664

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bengkulu      ID  -3.8004  102.2655     78.64        85         100
# 1       Honiara      SB  -9.4333  159.9500     78.06        87          59
# 2     Cape Town      ZA -33.9258   18.4232     73.09        49          81
# 3    Teloloapan      MX  18.3500  -99.8500     63.66        84          61
# 4      Victoria      HK  22.2855  114.1577     77.32        78          97
# 5     Tuatapere      NZ -46.1333  167.6833     39.58        87          46
# 6      Jinchang      CN  38.4953  102.1739     41.76        42          59
# 7  Punta Arenas      CL -53.1500  -70.9167     48.31        57           0
# 8      Hermanus      ZA -34.4187   19.2345     70.90        85         100
# 9         Airai      TL  -8.9266  125.4092     62.22        89          93
#
#    Wind Speed Current Description
# 0        3.13          light rain
# 1        5.79       broken clouds
# 2        9.26       broken clouds
# 3        0.96       broken clouds
# 4        1.01          light rain
# 5        4.68    scattered clouds
# 6        1.59       broken clouds
# 7       12.66           clear sky
# 8       10.31     overcast clouds
# 9        1.28     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# # Deliverable 2
